// %% [markdown]
// ## Documentation
//
// To read more about the search after parameter, checkout the docs [here](https://www.elastic.co/guide/en/elasticsearch/reference/8.15/paginate-search-results.html#search-after).
//
// ![search_after_docs](../images/search_after_docs.png)

// %% [markdown]
// ## Connect to ElasticSearch

// %%
import { Client } from "npm:@elastic/elasticsearch";
import { load } from "https://deno.land/std/dotenv/mod.ts";

const env = await load({ envPath: "../.env" });

const client = new Client({
  node: env.ELASTICSEARCH_NODE,
  auth: {
    apiKey: env.ELASTICSEARCH_API_KEY,
  },
});

const info = await client.info();
console.log(info);
// Out:
// {
//   name: "fead23d3120d",
//   cluster_name: "docker-cluster",
//   cluster_uuid: "v3fUyW9OReext6IjPiOCqg",
//   version: {
//     number: "8.17.4",
//     build_flavor: "default",
//     build_type: "docker",
//     build_hash: "c63c7f5f8ce7d2e4805b7b3d842e7e792d84dda1",
//     build_date: "2025-03-20T15:39:59.811110136Z",
//     build_snapshot: false,
//     lucene_version: "9.12.0",
//     minimum_wire_compatibility_version: "7.17.0",
//     minimum_index_compatibility_version: "7.0.0"
//   },
//   tagline: "You Know, for Search"
// }

// %% [markdown]
// ## Create index

// %%
await client.indices.delete({ index: "my_index", ignore_unavailable: true });
await client.indices.create({
  index: "my_index",
  mappings: {
    properties: {
      id: { type: "keyword" },
      value: { type: "float" },
      description: { type: "text" },
      category: { type: "keyword" },
      timestamp: { type: "date" },
    },
  },
});
// Out:
// { acknowledged: true, shards_acknowledged: true, index: "my_index" }

// %% [markdown]
// Let's index the documents.

// %% [markdown]
// The documents will be duplicated to create a total of `100,000` documents. This is done to compare the `from/size` method with the `search_after` method.

// %%
import data from "../data/dummy_data_3.json" with { type: "json" };

type Document = {
  id?: string;
  timestamp?: string;
  value: number;
  category: string;
  description: string;
};

function generateBulkData(baseDocuments: Document[], targetSize = 100000): Document[] {
  const documents: Document[] = [];
  const baseCount = baseDocuments.length;
  const duplicationsNeeded = Math.floor(targetSize / baseCount);
  const baseTimestamp = new Date();

  for (let i = 0; i < duplicationsNeeded; i++) {
    for (const document of baseDocuments) {
      const newDoc: Document = { ...document };
      newDoc.id = `doc_${documents.length}`;
      newDoc.value = document.value + (Math.random() * 20 - 10); // random float between -10 and 10
      const timestamp = new Date(baseTimestamp.getTime() - documents.length * 60 * 1000);
      newDoc.timestamp = timestamp.toISOString();
      documents.push(newDoc);
    }
  }

  return documents;
}

const documents = generateBulkData(data, 100000);

console.log(documents.length);
// Out:
// 100000

// %% [markdown]
// Since, we have duplicated the dummy data so much. Let's use the `bulk API` since we learned it before to index all those documents rapidly.

// %%
const operations = [];
for (const document of documents) {
  operations.push({
    index: {
      _index: "my_index",
    },
  });
  operations.push(document);
}

await client.bulk({
  operations,
});
// Out:
// {
//   errors: false,
//   took: 1817,
//   items: [
//     {
//       index: {
//         _index: "my_index",
//         _id: "voccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 0,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "v4ccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 1,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "wIccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 2,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "wYccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 3,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "woccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 4,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "w4ccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 5,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "xIccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 6,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "xYccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 7,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "xoccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 8,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "x4ccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 9,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "yIccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 10,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "yYccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 11,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "yoccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 12,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "y4ccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 13,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "zIccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 14,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "zYccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 15,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "zoccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 16,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "z4ccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 17,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "0IccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 18,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "0YccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 19,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "0occGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 20,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "04ccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 21,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "1IccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 22,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "1YccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 23,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "1occGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 24,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "14ccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 25,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "2IccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 26,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "2YccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 27,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "2occGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 28,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "24ccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 29,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "3IccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 30,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "3YccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 31,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "3occGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 32,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "34ccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 33,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "4IccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 34,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "4YccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 35,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "4occGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 36,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "44ccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 37,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "5IccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 38,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "5YccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 39,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "5occGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 40,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "54ccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 41,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "6IccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 42,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "6YccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 43,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "6occGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 44,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "64ccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 45,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "7IccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 46,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "7YccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 47,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "7occGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 48,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "74ccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 49,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "8IccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 50,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "8YccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 51,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "8occGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 52,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "84ccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 53,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "9IccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 54,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "9YccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 55,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "9occGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 56,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "94ccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 57,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "-IccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 58,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "-YccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 59,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "-occGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 60,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "-4ccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 61,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "_IccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 62,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "_YccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 63,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "_occGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 64,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "_4ccGpYBkrY7cs0F4otB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 65,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "AIccGpYBkrY7cs0F4oxB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 66,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "AYccGpYBkrY7cs0F4oxB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 67,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "AoccGpYBkrY7cs0F4oxB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 68,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "A4ccGpYBkrY7cs0F4oxB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 69,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "BIccGpYBkrY7cs0F4oxB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 70,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "BYccGpYBkrY7cs0F4oxB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 71,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "BoccGpYBkrY7cs0F4oxB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 72,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "B4ccGpYBkrY7cs0F4oxB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 73,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "CIccGpYBkrY7cs0F4oxB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 74,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "CYccGpYBkrY7cs0F4oxB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 75,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "CoccGpYBkrY7cs0F4oxB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 76,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "C4ccGpYBkrY7cs0F4oxB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 77,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "DIccGpYBkrY7cs0F4oxB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 78,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "DYccGpYBkrY7cs0F4oxB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 79,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "DoccGpYBkrY7cs0F4oxB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 80,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "D4ccGpYBkrY7cs0F4oxB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 81,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "EIccGpYBkrY7cs0F4oxB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 82,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "EYccGpYBkrY7cs0F4oxB",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 83,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "EoccGpYBkrY7cs0F4oxC",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 84,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "E4ccGpYBkrY7cs0F4oxC",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 85,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "FIccGpYBkrY7cs0F4oxC",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 86,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "FYccGpYBkrY7cs0F4oxC",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 87,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "FoccGpYBkrY7cs0F4oxC",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 88,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "F4ccGpYBkrY7cs0F4oxC",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 89,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "GIccGpYBkrY7cs0F4oxC",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 90,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "GYccGpYBkrY7cs0F4oxC",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 91,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "GoccGpYBkrY7cs0F4oxC",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 92,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "G4ccGpYBkrY7cs0F4oxC",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 93,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "HIccGpYBkrY7cs0F4oxC",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 94,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "HYccGpYBkrY7cs0F4oxC",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 95,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "HoccGpYBkrY7cs0F4oxC",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 96,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "H4ccGpYBkrY7cs0F4oxC",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 97,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "IIccGpYBkrY7cs0F4oxC",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 98,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "IYccGpYBkrY7cs0F4oxC",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 99,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     ... 99900 more items
//   ]
// }

// %% [markdown]
// ## From / Size method

// %% [markdown]
// To use the `from/size` method, include two parameters in your query: `from`, which specifies the number of documents to skip, and `size`, which tells Elasticsearch how many documents to return.

// %%
const response = await client.search({
  index: "my_index",
  from: 0,
  size: 10,
  sort: {
    timestamp: "desc",
    id: "desc",
  },
});

const hits = response.hits.hits;
for (const hit of hits) {
  console.log(hit._source.id);
}
// Out:
// doc_0
// doc_1
// doc_2
// doc_3
// doc_4
// doc_5
// doc_6
// doc_7
// doc_8
// doc_9

// %% [markdown]
// To retrieve the next batch of documents, adjust the `from` parameter from 0 to 10.

// %%
const response = await client.search({
  index: "my_index",
  from: 10, // Adjust here
  size: 10,
  sort: {
    timestamp: "desc",
    id: "desc",
  },
});

const hits = response.hits.hits;
for (const hit of hits) {
  console.log(hit._source.id);
}
// Out:
// doc_10
// doc_11
// doc_12
// doc_13
// doc_14
// doc_15
// doc_16
// doc_17
// doc_18
// doc_19

// %% [markdown]
// ## Search after method

// %% [markdown]
// To use the `search_after` method, include the following parameters in your query:
//
// 1. **size**: Specifies the number of documents to retrieve in each batch, similar to the `size` parameter in `from/size`.
//
// 2. **sort**: The `search_after` method requires specifying one or more fields to sort the results, such as `timestamp` or `id`. Sorting ensures a consistent order for navigating through result pages.

// %%
const response = await client.search({
  index: "my_index",
  from: 0,
  size: 10,
  sort: {
    timestamp: "desc",
    id: "desc",
  },
});

const hits = response.hits.hits;
for (const hit of hits) {
  console.log("Document ID:", hit._source.id);
  console.log("Value:", hit._source.value);
}
// Out:
// Document ID: doc_0
// Value: 19.928982280872738
// Document ID: doc_1
// Value: 108.96828524704071
// Document ID: doc_2
// Value: 8.22266896005628
// Document ID: doc_3
// Value: 155.40614116869534
// Document ID: doc_4
// Value: 31.109293462253152
// Document ID: doc_5
// Value: 7.925037262386985
// Document ID: doc_6
// Value: 50.848438746922334
// Document ID: doc_7
// Value: 307.0562204352602
// Document ID: doc_8
// Value: 10.419580785486556
// Document ID: doc_9
// Value: 73.20593164852329

// %% [markdown]
// To retrieve the next batch of documents using `search_after`, you’ll pass the `sort` values from the last document of the previous batch to the `search_after` parameter in the subsequent query.

// %%
const lastSortValue = hits[hits.length - 1].sort;

const response = await client.search({
  index: "my_index",
  size: 10,
  sort: {
    timestamp: "desc",
    id: "desc",
  },
  search_after: lastSortValue,
});

const hits = response.hits.hits;
for (const hit of hits) {
  console.log("Document ID:", hit._source.id);
  console.log("Value:", hit._source.value);
}
// Out:
// Document ID: doc_10
// Value: 12.231060483336362
// Document ID: doc_11
// Value: 107.6631114805679
// Document ID: doc_12
// Value: 5.641338290160385
// Document ID: doc_13
// Value: 155.62636621694477
// Document ID: doc_14
// Value: 21.497208772289675
// Document ID: doc_15
// Value: -3.1885614726155262
// Document ID: doc_16
// Value: 58.331152202624835
// Document ID: doc_17
// Value: 302.6084141960815
// Document ID: doc_18
// Value: 19.07907910498851
// Document ID: doc_19
// Value: 62.73603487529942

// %% [markdown]
// ## Conclusion

// %% [markdown]
// For larger indexes, it's recommended to use the `search_after` method. For smaller indexes, both methods work well.
