// %% [markdown]
// ## Documentation
//
// To read more about the search by Query DSL, visit the docs [Aggregations](https://www.elastic.co/guide/en/elasticsearch/reference/current/search-aggregations.html), [here](https://www.elastic.co/guide/en/elasticsearch/reference/current/search-your-data.html) and [here](https://www.elastic.co/guide/en/elasticsearch/reference/current/search-search.html).
//
// ![search_aggregations_docs](../images/search_aggregations_docs.png)

// %% [markdown]
// ## Connect to ElasticSearch

// %%
import { Client } from "npm:@elastic/elasticsearch";
import { load } from "https://deno.land/std/dotenv/mod.ts";

const env = await load({ envPath: "../.env" });

const client = new Client({
  node: env.ELASTICSEARCH_NODE,
  auth: {
    apiKey: env.ELASTICSEARCH_API_KEY,
  },
});

const info = await client.info();
console.log(info);
// Out:
// {
//   name: "fead23d3120d",
//   cluster_name: "docker-cluster",
//   cluster_uuid: "v3fUyW9OReext6IjPiOCqg",
//   version: {
//     number: "8.17.4",
//     build_flavor: "default",
//     build_type: "docker",
//     build_hash: "c63c7f5f8ce7d2e4805b7b3d842e7e792d84dda1",
//     build_date: "2025-03-20T15:39:59.811110136Z",
//     build_snapshot: false,
//     lucene_version: "9.12.0",
//     minimum_wire_compatibility_version: "7.17.0",
//     minimum_index_compatibility_version: "7.0.0"
//   },
//   tagline: "You Know, for Search"
// }

// %% [markdown]
// ## Create index

// %%
await client.indices.delete({ index: "my_index", ignore_unavailable: true });
await client.indices.create({ index: "my_index" });
// Out:
// { acknowledged: true, shards_acknowledged: true, index: "my_index" }

// %% [markdown]
// Let's index the documents.

// %%
import data from "../data/dummy_data_2.json" with { type: "json" };

function repeatArrayThousandTime(arr: any[]) {
  const result = [];
  for (let i = 0; i < 1000; i++) {
      result.push(...arr);
  }
  return result;
}

const dummyData = repeatArrayThousandTime(data);

console.log(dummyData.length);
// Out:
// 5000

// %% [markdown]
// Since, we have duplicated the dummy data so much. Let's use the `bulk API` since we learned it before to index all those documents rapidly.

// %%
const operations = [];
for (const document of dummyData) {
  operations.push({
    index: {
      _index: "my_index",
    },
  });
  operations.push(document);
}

await client.bulk({
  operations,
});
// Out:
// {
//   errors: false,
//   took: 200,
//   items: [
//     {
//       index: {
//         _index: "my_index",
//         _id: "RMi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 0,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "Rci5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 1,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "Rsi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 2,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "R8i5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 3,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "SMi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 4,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "Sci5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 5,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "Ssi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 6,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "S8i5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 7,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "TMi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 8,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "Tci5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 9,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "Tsi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 10,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "T8i5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 11,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "UMi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 12,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "Uci5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 13,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "Usi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 14,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "U8i5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 15,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "VMi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 16,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "Vci5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 17,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "Vsi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 18,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "V8i5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 19,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "WMi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 20,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "Wci5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 21,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "Wsi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 22,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "W8i5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 23,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "XMi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 24,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "Xci5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 25,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "Xsi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 26,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "X8i5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 27,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "YMi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 28,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "Yci5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 29,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "Ysi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 30,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "Y8i5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 31,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "ZMi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 32,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "Zci5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 33,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "Zsi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 34,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "Z8i5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 35,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "aMi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 36,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "aci5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 37,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "asi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 38,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "a8i5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 39,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "bMi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 40,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "bci5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 41,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "bsi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 42,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "b8i5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 43,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "cMi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 44,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "cci5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 45,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "csi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 46,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "c8i5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 47,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "dMi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 48,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "dci5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 49,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "dsi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 50,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "d8i5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 51,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "eMi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 52,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "eci5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 53,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "esi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 54,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "e8i5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 55,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "fMi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 56,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "fci5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 57,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "fsi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 58,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "f8i5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 59,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "gMi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 60,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "gci5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 61,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "gsi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 62,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "g8i5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 63,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "hMi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 64,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "hci5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 65,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "hsi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 66,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "h8i5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 67,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "iMi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 68,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "ici5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 69,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "isi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 70,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "i8i5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 71,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "jMi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 72,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "jci5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 73,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "jsi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 74,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "j8i5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 75,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "kMi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 76,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "kci5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 77,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "ksi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 78,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "k8i5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 79,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "lMi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 80,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "lci5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 81,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "lsi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 82,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "l8i5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 83,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "mMi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 84,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "mci5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 85,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "msi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 86,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "m8i5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 87,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "nMi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 88,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "nci5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 89,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "nsi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 90,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "n8i5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 91,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "oMi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 92,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "oci5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 93,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "osi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 94,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "o8i5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 95,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "pMi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 96,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "pci5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 97,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "psi5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 98,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     {
//       index: {
//         _index: "my_index",
//         _id: "p8i5AZYBo7TaDttMc2dx",
//         _version: 1,
//         result: "created",
//         _shards: { total: 2, successful: 1, failed: 0 },
//         _seq_no: 99,
//         _primary_term: 1,
//         status: 201
//       }
//     },
//     ... 4900 more items
//   ]
// }

// %% [markdown]
// ## Aggregations

// %% [markdown]
// In this example, we perform an aggregation to calculate the average value of the `age` field across all documents that match the query. The result of the aggregation is stored in the `averageAge` key.

// %%
const response = await client.search({
  index: "my_index",
  query: {
    match_all: {},
  },
  aggs: {
    averageAge: {
      avg: {
        field: "age",
      },
    },
  },
});

console.log(`Average age: ${response.aggregations.averageAge.value}`);
// Out:
// Average age: 33.4

// %% [markdown]
// ### Combining size, from, timeout, and aggs

// %% [markdown]
// Here we combine multiple parameters: we limit the results to 5 documents (`size`), skip the first 20 documents (`from`), set a timeout of 5 seconds (`timeout`), and perform a maximum aggregation (`aggs`) on the `price` field. This demonstrates how to use multiple search parameters together.

// %%
const response = await client.search({
  index: "my_index",
  query: {
    match: {
      message: "yes, keyword included",
    },
  },
  aggs: {
    maxPrice: {
      max: {
        field: "price",
      },
    },
  },
  size: 5,
  from: 20,
  timeout: "5s",
});

for (const hit of response.hits.hits) {
  console.log(hit._source);
}

console.log(`Max price: ${response.aggregations.maxPrice.value}`);
// Out:
// {
//   message: "Randomized result: yes, keyword included.",
//   age: 38,
//   price: 149.25
// }
// {
//   message: "Randomized result: yes, keyword included.",
//   age: 38,
//   price: 149.25
// }
// {
//   message: "Randomized result: yes, keyword included.",
//   age: 38,
//   price: 149.25
// }
// {
//   message: "Randomized result: yes, keyword included.",
//   age: 38,
//   price: 149.25
// }
// {
//   message: "Randomized result: yes, keyword included.",
//   age: 38,
//   price: 149.25
// }
// Max price: 199.89999389648438
